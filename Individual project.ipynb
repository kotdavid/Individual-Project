# %% [markdown]
# # Kot David Adhal Nguar
# # Master in Data Science
# # HackRank

# %% [markdown]
# # Problem 1
# # Building skills in Python
# # Introduction to Python World

# %%
import os
# Get current working directory
print(os.getcwd())

# %%
# Print Hello, World!
k = ("Hello," " " "World!")
print(k)

# %%
import math
import os
import random
import re
import sys

n = int(input().strip())

if n % 2 == 1:
    print("Weird")
elif 2 <= n <= 5:
    print("Not Weird")
elif 6 <= n <= 20:
    print("Weird")
else:  # n is even and > 20
    print("Not Weird")

# %%
if __name__ == '__main__':
    a = int(input().strip())
    b = int(input().strip())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
if __name__ == '__main__':
    a = int(input().strip())
    b = int(input().strip())
    print(a // b)
    print(a / b)

# %%
if __name__ == '__main__':
    n = int(input().strip())
    for i in range(n):
        print(i*i)

# %%
# Write a function I
if (year%4==0 and year%100!=0) or year%400==0:
    leap=True
elif year%100==0 and year%4!=0 or year%400!=0:
    leap=False
return leap
year = int(input())

# %%
# Capitalize 

# Complete the solve function below.
def solve(s):
     # Split the string by spaces and capitalize each word properly
    return ' '.join(word.capitalize() for word in s.split(' '))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = solve(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
# Merge the tools

def merge_the_tools(string, k):
    # your code goes here
 # Loop over the string in steps of k
    for i in range(0, len(string), k):
        substring = string[i:i + k]
        seen = ''
        # Keep only first occurrence of each character
        for ch in substring:
            if ch not in seen:
                seen += ch
        print(seen)
if __name__ == '__main__':
    string, k = input(), int(input())
    merge_the_tools(string, k)

# %%
# String Split and Join

def split_and_join(line):
   # Split the string into a list where each word is separated by a space
    words = line.split(" ")
    # Join the list into a single string with '-' as the separator
    return "-".join(words)

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
# What is your name 

# Complete the 'print_full_name' function below.
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    print(f"Hello {first} {last}! You just delved into python.")

if __name__ == '__main__':
    first_name = input()
    last_name = input()
    print_full_name(first_name, last_name)

# %%
# Mutations

def mutate_string(string, position, character):
    return string[:position] + character + string[position+1:]


if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)

# %%
# Find a string

def count_substring(string, sub_string):
    count = 0
    for i in range(len(string) - len(sub_string) + 1):
        if string[i:i + len(sub_string)] == sub_string:
            count += 1
    return count

if __name__ == '__main__':
    string = input().strip()
    sub_string = input().strip()
    
    count = count_substring(string, sub_string)
    print(count)

# %%
# String validations 

if __name__ == '__main__':
    s = input()
    print(any(c.isalnum() for c in s))  # Alphanumeric
    print(any(c.isalpha() for c in s))  # Alphabetical
    print(any(c.isdigit() for c in s))  # Digits
    print(any(c.islower() for c in s))  # Lowercase
    print(any(c.isupper() for c in s))  # Uppercase

# %%
# Text aligment

#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c * i).rjust(thickness - 1) + c + (c * i).ljust(thickness - 1))
#Top Pillars
for i in range(thickness + 1):
    print((c * thickness).center(thickness * 2) + (c * thickness).center(thickness * 6))
#Middle Belt
for i in range((thickness + 1) // 2):
    print((c * thickness * 5).center(thickness * 6))

#Bottom Pillars
for i in range(thickness + 1):
    print((c * thickness).center(thickness * 2) + (c * thickness).center(thickness * 6))

#Bottom Cone
for i in range(thickness):
    print(((c * (thickness - i - 1)).rjust(thickness) + c +
           (c * (thickness - i - 1)).ljust(thickness)).rjust(thickness * 6))

# %%
# Text wrap

ort textwrap

def wrap(string, max_width):
    return '\n'.join(textwrap.wrap(string, max_width))

if __name__ == '__main__':
    string, max_width = input(), int(input())
    result = wrap(string, max_width)
    print(result)

# %%
# string formatting

def print_formatted(number):
    width = len(bin(number)) - 2  # width based on binary representation
    for i in range(1, number + 1):
        deci = str(i)
        octa = oct(i)[2:]
        hexa = hex(i)[2:].upper()
        bina = bin(i)[2:]
        print(f"{deci:>{width}} {octa:>{width}} {hexa:>{width}} {bina:>{width}}")
if __name__ == '__main__':
    n = int(input())
    print_formatted(n)

# %%
# Designer Door Mat

N, M = map(int, input().split())

# Top part
for i in range(1, N, 2):
    pattern = (".|." * i).center(M, "-")
    print(pattern)

# Center part
print("WELCOME".center(M, "-"))

# Bottom part
for i in range(N - 2, 0, -2):
    pattern = (".|." * i).center(M, "-")
    print(pattern)

# %%
# The minion game

def minion_game(string):
    vowels = 'AEIOU'
    kevin_score = 0
    stuart_score = 0
    length = len(string)

    for i in range(length):
        # Number of substrings starting at index i = len(string) - i
        if string[i] in vowels:
            kevin_score += length - i
        else:
            stuart_score += length - i

    if kevin_score > stuart_score:
        print(f"Kevin {kevin_score}")
    elif stuart_score > kevin_score:
        print(f"Stuart {stuart_score}")
    else:
        print("Draw")

if __name__ == '__main__':
    s = input()
    minion_game(s)

# %%
# sWAP cASE

def swap_case(s):
    return s.swapcase()

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)

# %%
# Introduction to Sets

def average(array):
      # Convert the list to a set to remove duplicates
    distinct_heights = set(array)
    
    # Compute the average
    avg = sum(distinct_heights) / len(distinct_heights)
    
    # Round to 3 decimal places
    return round(avg, 3)

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)

# %%
# Sets Symmetric Difference

# Read input for first set
m = int(input())
a = set(map(int, input().split()))

# Read input for second set
n = int(input())
b = set(map(int, input().split()))

# Compute symmetric difference
sym_diff = a.symmetric_difference(b)  # or a ^ b

# Print each element in ascending order
for num in sorted(sym_diff):
    print(num)

# %%
# Read the number of stamps
n = int(input())

# Initialize an empty set to store unique country names
countries = set()

# Read each country's stamp and add to the set
for _ in range(n):
    country = input().strip()
    countries.add(country)

# Print the total number of distinct countries
print(len(countries))

# %%
# Set .discard(), .remove() & .pop()

# Read the number of elements
n = int(input())

# Read the elements and convert to a set of integers
s = set(map(int, input().split()))

# Read the number of commands
N = int(input())

# Execute each command
for _ in range(N):
    command = input().split()  # Split command into operation and possible argument
    if command[0] == "pop":
        s.pop()  # pop removes an arbitrary element
    elif command[0] == "remove":
        s.remove(int(command[1]))  # remove the specified element
    elif command[0] == "discard":
        s.discard(int(command[1]))  # discard the specified element

# Print the sum of the remaining elements in the set
print(sum(s))

# %%
# Set .union() Operation

# Read number of students subscribed to English newspaper
n = int(input())
english = set(map(int, input().split()))

# Read number of students subscribed to French newspaper
m = int(input())
french = set(map(int, input().split()))

# Find the union of both sets (students with at least one subscription)
all_students = english.union(french)  # or english | french

# Print the total number of students
print(len(all_students))

# %%
# Set .intersection() Operation

# Read number of students subscribed to English newspaper
n = int(input())
english = set(map(int, input().split()))

# Read number of students subscribed to French newspaper
m = int(input())
french = set(map(int, input().split()))

# Find students with both subscriptions
both = english & french  # or english.intersection(french)

# Print the total number of students with both subscriptions
print(len(both))

# %%
# Set .difference() Operation

# Read number of students subscribed to English newspaper
n = int(input())
english = set(map(int, input().split()))

# Read number of students subscribed to French newspaper
m = int(input())
french = set(map(int, input().split()))

# Find students with only English subscriptions
english_only = english - french  # or english.difference(french)

# Print the total number of students with only English subscriptions
print(len(english_only))

# %%
# Set .symmetric_difference() Operation

# Read number of students subscribed to English newspaper
n = int(input())
english = set(map(int, input().split()))

# Read number of students subscribed to French newspaper
m = int(input())
french = set(map(int, input().split()))

# Find students with subscriptions to English or French but not both
either_not_both = english.symmetric_difference(french)  # or english ^ french

# Print the total number of such students
print(len(either_not_both))

# %%
# Set Mutations

# Read number of elements in the main set
n = int(input())
A = set(map(int, input().split()))

# Read number of other sets / operations
N = int(input())

# Execute each operation
for _ in range(N):
    command_line = input().split()  # e.g., "intersection_update 10"
    command = command_line[0]       # operation name
    m = int(command_line[1])        # size of the other set (not used directly)
    
    other_set = set(map(int, input().split()))
    
    # Execute the mutation operation
    if command == "update":
        A.update(other_set)
    elif command == "intersection_update":
        A.intersection_update(other_set)
    elif command == "difference_update":
        A.difference_update(other_set)
    elif command == "symmetric_difference_update":
        A.symmetric_difference_update(other_set)

# Print the sum of elements in the mutated set
print(sum(A))

# %%
# The Captain's Room

# Read the size of each group
k = int(input())

# Read the list of room numbers
rooms = list(map(int, input().split()))

# Convert the list to a set to get unique room numbers
unique_rooms = set(rooms)

# Use the formula: Captain's room = (k * sum(unique_rooms) - sum(rooms)) // (k - 1)
captain_room = (k * sum(unique_rooms) - sum(rooms)) // (k - 1)

print(captain_room)

# %%
# Check Subset

# Read number of test cases
T = int(input())

for _ in range(T):
    # Read set A
    n = int(input())
    A = set(map(int, input().split()))
    
    # Read set B
    m = int(input())
    B = set(map(int, input().split()))
    
    # Check if A is a subset of B and print the result
    print(A.issubset(B))

# %%
# Check Strict Superset

# Read the main set
A = set(map(int, input().split()))

# Read the number of other sets
n = int(input())

# Initialize a flag as True
is_strict_superset = True

for _ in range(n):
    other_set = set(map(int, input().split()))
    
    # Check if A is a strict superset of the other set
    if not (A > other_set):  # '>' checks for strict superset
        is_strict_superset = False
        break  # No need to check further if one fails

print(is_strict_superset)

# %%
# No Idea!

# Read the first line: n (array size) and m (size of like/dislike sets, unused here)

n, m = map(int, input().split())

# Read the array
arr = list(map(int, input().split()))

# Read the like set
A = set(map(int, input().split()))

# Read the dislike set
B = set(map(int, input().split()))

# Initialize happiness
happiness = 0

# Calculate happiness
for x in arr:
    if x in A:
        happiness += 1
    elif x in B:
        happiness -= 1

print(happiness)

# %%
# collections.Counter()

from collections import Counter

# Read number of shoes
n = int(input())

# Read list of shoe sizes
shoes = list(map(int, input().split()))

# Count the available shoes by size
inventory = Counter(shoes)

# Read number of customers
m = int(input())

# Initialize total money earned
earnings = 0

# Process each customer
for _ in range(m):
    size, price = map(int, input().split())
    
    # If the desired size is available
    if inventory[size] > 0:
        earnings += price      # Add price to earnings
        inventory[size] -= 1   # Reduce available stock by 1

print(earnings)

# %%
# DefaultDict Tutorial

from collections import defaultdict

# Read n (size of Group A) and m (size of Group B)
n, m = map(int, input().split())

# Read Group A words
group_a = [input().strip() for _ in range(n)]

# Read Group B words
group_b = [input().strip() for _ in range(m)]

# Create a defaultdict to store positions of each word in Group A
positions = defaultdict(list)

for index, word in enumerate(group_a, start=1):  # 1-indexed positions
    positions[word].append(index)

# For each word in Group B, print positions or -1 if not found
for word in group_b:
    if word in positions:
        print(" ".join(map(str, positions[word])))
    else:
        print(-1)

# %%
# Collections.namedtuple()

from collections import namedtuple

n = int(input())
columns = input().split()
Student = namedtuple('Student', columns)
total = sum(int(Student(*input().split()).MARKS) for _ in range(n))
print(f"{total/n:.2f}")

# %%
# Collections.OrderedDict()

from collections import OrderedDict

n = int(input())
items = OrderedDict()

for _ in range(n):
    *name_parts, price = input().split()
    item_name = " ".join(name_parts)
    price = int(price)
    
    if item_name in items:
        items[item_name] += price
    else:
        items[item_name] = price

for item, total in items.items():
    print(f"{item} {total}")

# %%
# Word Order

from collections import OrderedDict

n = int(input())
word_count = OrderedDict()

for _ in range(n):
    word = input().strip()
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

# Print number of distinct words
print(len(word_count))

# Print occurrences in order of first appearance
print(" ".join(map(str, word_count.values())))

# %%
# Collections.deque()

from collections import deque

d = deque()
n = int(input())

for _ in range(n):
    command = input().split()
    if len(command) == 2:
        getattr(d, command[0])(command[1])  # Call method with argument
    else:
        getattr(d, command[0])()            # Call method without argument

print(" ".join(d))

# %%
# Piling Up!

for _ in range(int(input())):
    n = int(input())
    cubes = list(map(int, input().split()))
    
    top = float('inf')  # The top of the pile can initially be infinitely high
    while cubes:
        if cubes[0] >= cubes[-1]:
            next_cube = cubes.pop(0)
        else:
            next_cube = cubes.pop()
        
        if next_cube > top:
            print("No")
            break
        top = next_cube
    else:
        print("Yes")

# %%
#  Company Logo
import math
import os
import random
import re
import sys

from collections import Counter

# Read input
s = input().strip()

# Count occurrences of each character
counter = Counter(s)

# Sort by count descending, then alphabetically
sorted_chars = sorted(counter.items(), key=lambda x: (-x[1], x[0]))

# Print top 3
for char, count in sorted_chars[:3]:
    print(char, count)

# %%
# Write a Function II
def is_leap(year):
    leap = False
    
    # Write your logic here
    if not year % 4:
        if (not leap % 100 and not year % 400) or year % 100 :
            leap = True
    return leap

year = int(input())

# %%
# Write a function III
def is_leap(year: int) -> bool:
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False


# Example usage:
years = [2000, 2400, 1800, 1900, 2100, 2200, 2300, 2500]
for y in years:
    print(f"{y}: {'Leap year' if is_leap(y) else 'Not a leap year'}")
# Out:
# 2000: Leap year
# 2400: Leap year
# 1800: Not a leap year
# 1900: Not a leap year
# 2100: Not a leap year
# 2200: Not a leap year
# 2300: Not a leap year
# 2500: Not a leap year

# %%
# Print function 
if __name__ == '__main__':
    n = int(input())
    for i in range(1, n+1):
        print(i, end="")

# %%
# Sum and Product
import numpy as np
N, M = map(int, input().split())
output = np.array([list(map(int, input().split())) 
for i in range(N)])
print(np.prod
(np.sum
(output, axis=0)))

# %%
# Min and Max
import numpy as np
N,M = map(int,input().split())
output = np.array([input().split() 
for _ in range(N)],int)
output = np.min(output,axis=1)
print(np.max(output))

# %%
# Mean, Variance, and Standard deviation (Std)
import numpy as np
N, M = map(int, input().split())
output = np.array([input().split() for _ in range(N)], int)
print(np.mean(output, axis=1))
print(np.var(output, axis=0))
print(round(np.std(output), 11))

# %%
# Dot and Cross
import numpy as np
N = int(input())
A = np.array([input().split() for _ in range(N)], int)
B= np.array([input().split() for _ in range(N)], int)
print(np.dot(A, B))

# %%
# Inner and Outer 
import numpy as np
A = np.array(input().split(), int)
B = np.array(input().split(), int)
print(np.inner(A, B))
print(np.outer(A, B))

# %%
# Polynomials 
import numpy as np
P = np.array(input().split(), float)
x = float(input())
print(np.polyval(P, x))

# %%
# Linear Algebra 
import numpy as np
N = int(input())
A = np.array([input().split() for _ in range(N)], float)
print(round(np.linalg.det(A), 2))

# %%
# Erros and Exceptions 
# Number of test cases
t = int(input())

for _ in range(t):
    try:
        a, b = input().split()
        print(int(a) // int(b))
    except ZeroDivisionError as e:
        print("Error Code:", e)
    except ValueError as e:
        print("Error Code:", e)

# %%
# Alphabetical Rangoli
def print_rangoli(size):
    import string
    alpha = string.ascii_lowercase

    # Generate the pattern lines
    lines = []
    for i in range(size):
        # Select letters for the current row
        s = "-".join(alpha[i:size])
        # Mirror the sequence around the center letter
        line = (s[::-1] + s[1:]).center(4*size - 3, "-")
        lines.append(line)

    # Print the rangoli
    print("\n".join(lines[::-1] + lines[1:]))

# Input and function call
if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)

# %%
# List comprehensions
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
# Using list comprehension
result = [[i, j, k] 
          for i in range(x + 1)
          for j in range(y + 1)
          for k in range(z + 1)
          if (i + j + k) != n]

print(result)

# %%
# Nested lists
if __name__ == '__main__':
    students = []
    for _ in range(int(input())):
        name = input()
        scores = float(input())
        students.append([name, scores])

# Extract all scores and find the second lowest one
scores = sorted({s[1] for s in students})  # use set to remove duplicates
second_lowest = scores[1]

# Find all students with the second lowest score
names = [s[0] for s in students if s[1] == second_lowest]

# Sort names alphabetically
names.sort()

# Print each name on a new line
for name in names:
    print(name)

# %%
#Find the percentage 
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    avg = sum(student_marks[query_name]) / len(student_marks[query_name])
    print(f"{avg:.2f}")

# %%
# lists
if __name__ == '__main__':
    N = int(input())

    my_list = []

    for _ in range(N):
        command = input().split()
        action = command[0]
        args = command[1:]

        if action == "insert":
            my_list.insert(int(args[0]), int(args[1]))
        elif action == "print":
            print(my_list)
        elif action == "remove":
            my_list.remove(int(args[0]))
        elif action == "append":
            my_list.append(int(args[0]))
        elif action == "sort":
            my_list.sort()
        elif action == "pop":
            my_list.pop()
        elif action == "reverse":
            my_list.reverse()

# %%
# Tuple
# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    t = tuple(integer_list)
    print(hash(t)) 
    
    # HackerRank’s Tuples problem was originally written for Python 2.

# In Python 3, the built-in hash() function produces different values because of hash randomization (a security feature introduced in Python 3.3).

# So even if the logic is correct, the hash output will differ from the one HackerRank expects.

# %%
# Find the Runners up score!
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())    
    # Remove duplicates and sort descending
    unique_scores = sorted(set(arr), reverse=True)
    
    # The runner-up is the second element
    print(unique_scores[1])

# %%
# Calender Module 
import calendar; month, day, year = map(int, input().split()); print(calendar.day_name[calendar.weekday(year, month, day)].upper())

# %%
# Time delta

import math
import os
import random
import re
import sys
from datetime import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    fmt = "%a %d %b %Y %H:%M:%S %z"
    time1 = datetime.strptime(t1, fmt)
    time2 = datetime.strptime(t2, fmt)
    return str(int(abs((time1 - time2).total_seconds())))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()
        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
# Map and lambda function 

cube = lambda x: x ** 3  # complete the lambda function

def fibonacci(n):
    # return a list of fibonacci numbers
    fib = [0, 1]
    for i in range(2, n):
        fib.append(fib[-1] + fib[-2])
    return fib[:n]

if __name__ == '__main__':
    n = int(input())
    print(list(map(cube, fibonacci(n))))

# %%
# Delect floating point number 

for _ in range(int(input())):
    s = input()
    try:
        # Check if conversion to float works
        float(s)
        # Check that there is exactly one '.' and at least one digit after it
        if s.count('.') == 1 and not s.endswith('.'):
            print(True)
        else:
            print(False)
    except:
        print(False)

# %%
# Standardize mobile number using decorators

def wrapper(f):
    def fun(l):
        # Standardize each phone number
        standardized = []
        for number in l:
            # Keep only last 10 digits
            number = number[-10:]
            # Format as +91 xxxxx xxxxx
            formatted = f"+91 {number[:5]} {number[5:]}"
            standardized.append(formatted)
        
        # Call the original function with formatted numbers
        return f(standardized)
    return fun

@wrapper
def sort_phone(l):
    print(*sorted(l), sep='\n')

if __name__ == '__main__':
    l = [input() for _ in range(int(input()))]
    sort_phone(l)

# %%
# Decorators 2 - name directory 

import operator

def person_lister(f):
    def inner(people):
        # Sort people by age (convert string to int for numeric sort)
        people.sort(key=lambda x: int(x[2]))
        # Apply the given function to each person
        return [f(person) for person in people]
    return inner

@person_lister
def name_format(person):
    return ("Mr. " if person[3] == "M" else "Ms. ") + person[0] + " " + person[1]

if __name__ == '__main__':
    people = [input().split() for i in range(int(input()))]
    print(*name_format(people), sep='\n')

# %%
# Map and Lambda Function

cube = lambda x:  x**3  # complete the lambda function 

def fibonacci(n):
  fib_list = []
  a, b = 0, 1
  for _ in range(n):
    fib_list.append(a)
    a, b = b, a + b
  return fib_list


if __name__ == '__main__':
    n = int(input())
    print(list(map(cube, fibonacci(n))))

# %%
# Re.split()

regex_pattern = r"[,.]"	# Do not delete 'r'.
import re
print("\n".join(re.split(regex_pattern, input())))

# %%
# Group(), Groups() & Groupdict()

import re

s = input()

# Look for first alphanumeric character repeated consecutively
match = re.search(r'([a-zA-Z0-9])\1', s)

if match:
    print(match.group(1))
else:
    print(-1)

# %%
# Validating Postal Codes

regex_integer_in_range = r"^[1-9][0-9]{5}$"	# Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"(\d)(?=\d\1)"	# Do not delete 'r'.


import re
P = input()

print (bool(re.match(regex_integer_in_range, P)) 
and len(re.findall(regex_alternating_repetitive_digit_pair, P)) < 2)

# %%
# Mod Divmod
# Read input values
a = int(input())
b = int(input())

# Print results
print(a // b)      # Integer division
print(a % b)       # Modulo
print(divmod(a, b))  # Tuple containing (quotient, remainder)

# %%
# Power - Mod Power

# Read input values
a = int(input())
b = int(input())
m = int(input())

# Print a^b
print(pow(a, b))

# Print (a^b) % m
print(pow(a, b, m))

# %%
# Integers Come In All Sizes
# Read input values
a = int(input())
b = int(input())
c = int(input())
d = int(input())

# Compute (a^b + c^d) and print
print(pow(a, b) + pow(c, d))

# %%
# Validating and Parsing Email Addresses

import re
import email.utils

# Number of input lines
n = int(input())

# Regex for a valid email
# Username: starts with a letter, followed by letters, digits, _, -, or .
# Domain: only letters
# Extension: only letters, 1 to 3 chars
email_regex = re.compile(r'^[a-zA-Z][\w\.-]*@[a-zA-Z]+\.[a-zA-Z]{1,3}$')

for _ in range(n):
    line = input()
    # Parse name and email using email.utils
    name, addr = email.utils.parseaddr(line)
    
    # Validate email
    if email_regex.match(addr):
        print(line)

# %% [markdown]
# #                   Problem 2
# #   Implementation of some algorithms in Python.

# %%
# Birthday Cake Candles

import math
import os
import random
import re
import sys

# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.

def birthdayCakeCandles(candles):
   tallest = max(candles)           # Find the tallest candle
   return candles.count(tallest)    # Count how many candles have that height

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Number Line Jumps

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    if v1 == v2:
        return "YES" if x1 == x2 else "NO"
    
    # Check if they can meet at the same position
    n = (x2 - x1) / (v1 - v2)
    
    if n >= 0 and n.is_integer():
        return "YES"
    else:
        return "NO"


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
# Viral Advertising

import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    shared = 5  # initial number of people who see the ad
    cumulative = 0
    
    for day in range(1, n + 1):
        liked = shared // 2          # half of them like it
        cumulative += liked          # add to total likes
        shared = liked * 3           # each liker shares with 3 friends
        
    return cumulative

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Recursive Digt Sum


import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k
#

def superDigit(n, k):
    # Helper function to compute super digit recursively
    def helper(num):
        if num < 10:
            return num
        # Sum of digits and recurse
        return helper(sum(int(d) for d in str(num)))
    
    # Compute initial sum = sum of digits in n * k
    initial_sum = sum(int(d) for d in n) * k
    
    # Compute super digit of the initial sum
    return helper(initial_sum)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Insertion Sort - Part 1

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    key = arr[-1]  # the last element to insert
    i = n - 2      # start from the second last index
    
    # Move elements greater than key one position ahead
    while i >= 0 and arr[i] > key:
        arr[i + 1] = arr[i]   # shift right
        print(" ".join(map(str, arr)))  # print intermediate step
        i -= 1
    
    arr[i + 1] = key  # insert key at the right position
    print(" ".join(map(str, arr)))  # print final array

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
# Insertion Sort - Part 2

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
      # The outer loop iterates from the second element (index 1) to the end.
    # The sub-array arr[0...i-1] is considered the sorted part.
    for i in range(1, n):
        # The 'key' is the element we want to insert into the sorted part.
        key = arr[i]
        
        # 'j' points to the last element in the sorted sub-array.
        j = i - 1
        
        # Move elements of the sorted part (arr[0...i-1]) that are
        # greater than the key to one position ahead of their current position.
        # This makes space for the key to be inserted.
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
            
        # Place the key at its correct sorted position.
        arr[j + 1] = key
        
        # As required, print the state of the array after each insertion.
        print(*arr)

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)
